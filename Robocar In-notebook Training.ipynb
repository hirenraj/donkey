# %%
# Make sure we're in SageMaker root
# %cd ~/SageMaker

# Install
# !pip install donkeycar==2.2.4
# Out:
# /home/ec2-user/SageMaker
# ...
# You are using pip version 9.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Create a new car using the library CLI
# !donkey createcar --path d2
# Out:
# using donkey v2.2.4 ...
# Creating car folder: d2
# making dir  d2
# Creating data & model folders.
# making dir  d2/models
# making dir  d2/data
# making dir  d2/logs
# Car app already exists. Delete it and rerun createcar to replace.
# Car config already exists. Delete it and rerun createcar to replace.
# Donkey setup complete.

# %%
# Copy from zipped data from S3 to the Notebook instance
# !aws s3 cp s3://your_bucket_name/tarballname.tar.gz /home/ec2-user/SageMaker/d2/data/
# Out:
# download: s3://escalona-sagemaker/robocartrainingdata/tarballname_kumo_fast.tar.gz to d2/data/tarballname_kumo_fast.tar.gz

# %%
# Unzip the data
# !tar -xzvf ~/SageMaker/d2/data/tarballname.tar.gz
# Out:
# home/pi/d2/data/tub_27_18-07-25/
# home/pi/d2/data/tub_27_18-07-25/record_165.json
# home/pi/d2/data/tub_27_18-07-25/238_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/408_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/602_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/record_855.json
# home/pi/d2/data/tub_27_18-07-25/453_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/record_704.json
# home/pi/d2/data/tub_27_18-07-25/432_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/806_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/record_1429.json
# home/pi/d2/data/tub_27_18-07-25/record_164.json
# home/pi/d2/data/tub_27_18-07-25/393_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/212_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/1228_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/1061_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/883_cam-image_array_.jpg
# home/pi/d2/data/tub_27_18-07-25/1238_cam-image_array_.jpg
# ...

# %%
# train the data on Notebook and output model in models directory
# !python d2/manage.py train --tub home/pi/d2/data/your_tub_name --model d2/models/your_model_name
# Out:
# using donkey v2.2.4 ...
# /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# loading config file: /home/ec2-user/SageMaker/d2/config.py
# config loaded
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1205: calling reduce_prod (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ...

# %%
# Copy model from Notebook to S3. Ensure you update the model name below to choose your model. 
# !aws s3 cp d2/models/your_model_name s3://your_bucket_name/your_model_name
# Out:
# upload: d2/models/kumo_fast to s3://escalona-sagemaker/robocartrainingdata/kumo_fast

# %%
#Next, jump back to your Robocar SSH session and pull down the model from S3.
